# %%
# !pip install sqlalchemy==1.3.9
# Out:
# ...
#      ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#      ----- ---------------------------------- 0.8/6.0 MB 4.8 MB/s eta 0:00:02
#      --------------------- ------------------ 3.1/6.0 MB 8.5 MB/s eta 0:00:01
#      ------------------------------------ --- 5.5/6.0 MB 9.8 MB/s eta 0:00:01
#      ---------------------------------------- 6.0/6.0 MB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp313-cp313-win_amd64.whl size=1142950 sha256=8dd4042407c7af7c607e13149d93a44290fbd940a4538dd311c9cde3c48f40bf
#   Stored in directory: c:\users\heinr\appdata\local\pip\cache\wheels\7f\0c\92\6ec5ca28eb22ed22341110143de753ec622045fbfc750edb26
# Successfully built sqlalchemy
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.39
# ...

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 10.6 MB/s eta 0:00:00
# ...
#
#   Attempting uninstall: sqlalchemy
#
#     Found existing installation: SQLAlchemy 1.3.9
#
#     Uninstalling SQLAlchemy-1.3.9:
#
#       Successfully uninstalled SQLAlchemy-1.3.9
#
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
# ...

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %%sql
#
# SELECT DISTINCT "Launch_Site"
# FROM SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %%
# %%sql
#
# SELECT *
# FROM SPACEXTBL
#     where "Launch_Site" like 'CCA%'
#     limit 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
# %%sql
# SELECT SUM("PAYLOAD_MASS__KG_") AS TotalPayloadMass
# FROM SPACEXTBL
# WHERE "Customer" = 'NASA (CRS)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %%
# %%sql
#
# SELECT AVG("PAYLOAD_MASS__KG_") AS AveragePayloadMass
# from SPACEXTBL
# WHERE "Booster_Version" = 'F9 v1.1';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2928.4,)]

# %%
# %%sql
#
# SELECT MIN("Date") AS FirstSuccessGroundPad
# FROM SPACEXTBL
# WHERE "Landing_Outcome" = 'Success (ground pad)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %%
# %%sql
#
# SELECT "Booster_Version"
# FROM SPACEXTBL
# WHERE "PAYLOAD_MASS__KG_" BETWEEN '4000' and '6000';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 v1.1',),
#  ('F9 v1.1 B1011',),
#  ('F9 v1.1 B1014',),
#  ('F9 v1.1 B1016',),
#  ('F9 FT B1020',),
#  ('F9 FT B1022',),
#  ('F9 FT B1026',),
#  ('F9 FT B1030',),
#  ('F9 FT  B1021.2',),
#  ('F9 FT B1032.1',),
#  ('F9 B4 B1040.1',),
#  ('F9 FT  B1031.2',),
#  ('F9 B4 B1043.1',),
#  ('F9 FT  B1032.2',),
#  ('F9 B4  B1040.2',),
#  ('F9 B5 B1046.2',),
#  ('F9 B5 B1047.2',),
#  ('F9 B5 B1046.3',),
#  ('F9 B5B1054',),
#  ('F9 B5 B1048.3',),
#  ('F9 B5 B1051.2 ',),
#  ('F9 B5B1060.1',),
#  ('F9 B5 B1058.2 ',),
#  ('F9 B5B1062.1',)]

# %%
# %%sql
#
# SELECT COUNT("Mission_Outcome")
# FROM SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(101,)]

# %%
# %%sql
#
# SELECT "Booster_Version", "PAYLOAD_MASS__KG_"
# FROM SPACEXTBL
# WHERE "PAYLOAD_MASS__KG_" = (
#     SELECT MAX("PAYLOAD_MASS__KG_")
#     FROM SPACEXTBL
# );
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1049.5', 15600),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1058.3 ', 15600),
#  ('F9 B5 B1051.6', 15600),
#  ('F9 B5 B1060.3', 15600),
#  ('F9 B5 B1049.7 ', 15600)]

# %%
# %%sql
# SELECT
#     substr("Date", 6, 2) AS MONTHNAME,
#     "Landing_Outcome",
#     "Booster_Version",
#     "Launch_Site"
# FROM SPACEXTBL
# WHERE substr("Date", 0, 5) = '2015'
#     and "Landing_Outcome" like 'Failure (drone ship)%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('04', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %%
# %%sql
# SELECT "Landing_Outcome", COUNT(*) as CountofLandingOutcomes
# FROM SPACEXTBL
# WHERE "Date" between '2010-06-04' and '2017-03-20'
# GROUP BY "Landing_Outcome"
# ORDER BY CountofLandingOutcomes DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]
